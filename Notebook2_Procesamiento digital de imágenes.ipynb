# %% [markdown]
# <center>
# <div style="color:;
#            display:fill;
#            border-radius:1px;
#            background-color: navy;
#            font-size:110%;
#            letter-spacing:0.3px">
#
# <h2 style="padding: 20px;
#               color:white;"> Notebook 2: Procesamiento digital de imágenes
# </h2>
# </div>

# %% [markdown]
# <center>
# <div style="color:;
#            display:fill;
#            border-radius:1px;
#            background-color: mediumblue;
#            font-size:110%;
#            letter-spacing:0.3px">
#
# <h2 style="padding: 20px;
#               color:white;"> Pillow
# </h2>
# </div>

# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
from IPython.display import display

# Abrir la imagen original
img_original = Image.open(r'/Users/roxanarachel/Desktop/tiburon.jpeg')

# Mostrar la imagen original en Jupyter Lab
display(img_original)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
# Abrir la imagen
img = Image.open(r'/Users/roxanarachel/Desktop/tiburon.jpeg')

# Rotar la imagen
nuevaimg = img.rotate(25)

# Mostrar la imagen rotada en Jupyter Lab
display(nuevaimg)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
from PIL import Image,ImageFilter 
#Ahora importamos 'ImageFilter" para los filtros
img = Image.open(r'/Users/roxanarachel/Desktop/tiburon.jpeg')
nuevaimg = img.filter(ImageFilter.BLUR)
display(nuevaimg)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img = Image.open(r'/Users/roxanarachel/Desktop/tiburon.jpeg')
nuevaimg = img.filter(ImageFilter.BoxBlur(50))  #Filtro de BoxBlur(50)
display(nuevaimg)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img = Image.open(r'/Users/roxanarachel/Desktop/tiburon.jpeg')
nuevaimg = img.filter(ImageFilter.CONTOUR)  #Filtro de CONTOUR
display(nuevaimg)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img = Image.open(r'/Users/roxanarachel/Desktop/tiburon.jpeg')
nuevaimg = img.filter(ImageFilter.EDGE_ENHANCE)  #Filtro de EDGE_ENHANCE
display(nuevaimg)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img = Image.open(r'/Users/roxanarachel/Desktop/tiburon.jpeg')
nuevaimg = img.filter(ImageFilter.EMBOSS)  #Filtro de EMBOSS
display(nuevaimg)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img = Image.open(r'/Users/roxanarachel/Desktop/tiburon.jpeg')
nuevaimg = img.filter(ImageFilter.FIND_EDGES)  #Filtro de FIND_EDGES
display(nuevaimg)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %% [markdown]
# <center>
# <div style="color:;
#            display:fill;
#            border-radius:1px;
#            background-color: skyblue;
#            font-size:110%;
#            letter-spacing:0.3px">
#
# <h2 style="padding: 20px;
#               color:white;"> OpenCV
# </h2>
# </div>

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install opencv-python

# %%
conda install -c conda-forge opencv
# Out:
# Error while loading conda entry point: conda-libmamba-solver (dlopen(/Users/roxanarachel/anaconda3/lib/python3.11/site-packages/libmambapy/bindings.cpython-311-darwin.so, 0x0002): Library not loaded: @rpath/libarchive.19.dylib
#   Referenced from: <027768CD-20C9-3E75-850D-35E842A32FA5> /Users/roxanarachel/anaconda3/lib/libmamba.2.0.0.dylib
#   Reason: tried: '/Users/roxanarachel/anaconda3/lib/libarchive.19.dylib' (no such file), '/Users/roxanarachel/anaconda3/lib/python3.11/site-packages/libmambapy/../../../libarchive.19.dylib' (no such file), '/Users/roxanarachel/anaconda3/lib/python3.11/site-packages/libmambapy/../../../libarchive.19.dylib' (no such file), '/Users/roxanarachel/anaconda3/bin/../lib/libarchive.19.dylib' (no such file), '/Users/roxanarachel/anaconda3/bin/../lib/libarchive.19.dylib' (no such file), '/usr/local/lib/libarchive.19.dylib' (no such file), '/usr/lib/libarchive.19.dylib' (no such file, not in dyld cache))
#
# ...

# %%
# !pip install matplotlib

# %%
import cv2
img = cv2.imread('/Users/roxanarachel/Desktop/arbol.jpeg')

# %%
img = cv2.imread('/Users/roxanarachel/Desktop/arbol.jpeg')
resized_img = cv2.resize(img, (500, 500))

# %%
from IPython.display import display, Image
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Ruta de la imagen original
ruta_imagen = '/Users/roxanarachel/Desktop/arbol.jpeg'

# Leer la imagen original
img_original = cv2.imread(ruta_imagen)

# Convertir de BGR a RGB
img_original_rgb = cv2.cvtColor(img_original, cv2.COLOR_BGR2RGB)

# Mostrar la imagen con matplotlib
plt.imshow(img_original_rgb)
plt.axis('off')
plt.show()

# %%
# Leer la imagen
img = cv2.imread('/Users/roxanarachel/Desktop/arbol.jpeg')

# Redimensionar la imagen (opcional)
resized_img = cv2.resize(img, (200, 500))

# Mostrar la imagen en Jupyter Lab
plt.imshow(cv2.cvtColor(resized_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
# Cargar la imagen en escala de grises
img = cv2.imread('/Users/roxanarachel/Desktop/arbol.jpeg', cv2.IMREAD_GRAYSCALE)

# Aplicar umbral binario
ret, thresh = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

# Mostrar la imagen original en Jupyter Lab
display(Image(data=cv2.imencode('.png', img)[1]))

# Mostrar la imagen umbralizada en Jupyter Lab
display(Image(data=cv2.imencode('.png', thresh)[1]))

# %%
# Cargar la imagen
img = cv2.imread('/Users/roxanarachel/Desktop/arbol.jpeg')

# Convertir la imagen a escala de grises
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Aplicar umbral binario
ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# Encontrar contornos
contornos, jerarquia = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Dibujar contornos en la imagen original
img_contornos = img.copy()
cv2.drawContours(img_contornos, contornos, -1, (0, 255, 0), 2)

# Mostrar la imagen original con contornos utilizando matplotlib
plt.imshow(cv2.cvtColor(img_contornos, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
# Cargar la imagen
img = cv2.imread('/Users/roxanarachel/Desktop/arbol.jpeg')

# Cambiar el tamaño de la imagen
resized_img = cv2.resize(img, (500, 500))

# Gira la imagen
(filas, columnas) = img.shape[:2]
M = cv2.getRotationMatrix2D((columnas/2, filas/2), 45, 1)
rotated_img = cv2.warpAffine(img, M, (columnas, filas))

# Recortar la imagen
imagen_recortada = img[100:300, 200:400]

# Mostrar las imágenes utilizando matplotlib
plt.figure(figsize=(10, 5))

plt.subplot(1, 4, 1), plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)), plt.title('Original')
plt.subplot(1, 4, 2), plt.imshow(cv2.cvtColor(resized_img, cv2.COLOR_BGR2RGB)), plt.title('Cambio de Tamaño')
plt.subplot(1, 4, 3), plt.imshow(cv2.cvtColor(rotated_img, cv2.COLOR_BGR2RGB)), plt.title('Rotación')
plt.subplot(1, 4, 4), plt.imshow(cv2.cvtColor(imagen_recortada, cv2.COLOR_BGR2RGB)), plt.title('Recorte')

plt.show()
